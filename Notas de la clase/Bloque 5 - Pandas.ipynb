# %% [markdown]
# # Pandas

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set_context(context = "paper")
sns.set_theme(style = "darkgrid")

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
df_car = sns.load_dataset("car_crashes")
df_car
# Out:
#     total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0    18.8     7.332    5.640          18.048       15.040       784.55
# 1    18.1     7.421    4.525          16.290       17.014      1053.48
# 2    18.6     6.510    5.208          15.624       17.856       899.47
# 3    22.4     4.032    5.824          21.056       21.280       827.34
# 4    12.0     4.200    3.360          10.920       10.680       878.41
# 5    13.6     5.032    3.808          10.744       12.920       835.50
# 6    10.8     4.968    3.888           9.396        8.856      1068.73
# 7    16.2     6.156    4.860          14.094       16.038      1137.87
# 8     5.9     2.006    1.593           5.900        5.900      1273.89
# 9    17.9     3.759    5.191          16.468       16.826      1160.13
# 10   15.6     2.964    3.900          14.820       14.508       913.15
# 11   17.5     9.450    7.175          14.350       15.225       861.18
# ...

# %%
type(df_car)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ## Datos de muestra en .csv y de internet

# %%
df_iris = pd.read_csv('https://raw.githubusercontent.com/mwaskom/seaborn-data/master/iris.csv')
df_iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df_iris["species"]#.unique()
# Out:
# 0         setosa
# 1         setosa
# 2         setosa
# 3         setosa
# 4         setosa
#          ...
# 145    virginica
# 146    virginica
# 147    virginica
# 148    virginica
# 149    virginica
# Name: species, Length: 150, dtype: object

# %%
df_iris.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
mascara = df_iris["species"] == "virginica"
mascara
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 145     True
# 146     True
# 147     True
# 148     True
# 149     True
# Name: species, Length: 150, dtype: bool

# %%
df_iris_virginica = df_iris.loc[mascara].drop(columns = ["species"])
df_iris_virginica
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 100           6.3          3.3           6.0          2.5
# 101           5.8          2.7           5.1          1.9
# 102           7.1          3.0           5.9          2.1
# 103           6.3          2.9           5.6          1.8
# 104           6.5          3.0           5.8          2.2
# 105           7.6          3.0           6.6          2.1
# 106           4.9          2.5           4.5          1.7
# 107           7.3          2.9           6.3          1.8
# 108           6.7          2.5           5.8          1.8
# 109           7.2          3.6           6.1          2.5
# 110           6.5          3.2           5.1          2.0
# 111           6.4          2.7           5.3          1.9
# 112           6.8          3.0           5.5          2.1
# 113           5.7          2.5           5.0          2.0
# 114           5.8          2.8           5.1          2.4
# ...

# %%
df_iris_setosa = df_iris.loc[df_iris["species"] == "setosa"].drop(columns = "species")
df_iris_setosa
# Out:
#     sepal_length  sepal_width  petal_length  petal_width
# 0            5.1          3.5           1.4          0.2
# 1            4.9          3.0           1.4          0.2
# 2            4.7          3.2           1.3          0.2
# 3            4.6          3.1           1.5          0.2
# 4            5.0          3.6           1.4          0.2
# 5            5.4          3.9           1.7          0.4
# 6            4.6          3.4           1.4          0.3
# 7            5.0          3.4           1.5          0.2
# 8            4.4          2.9           1.4          0.2
# 9            4.9          3.1           1.5          0.1
# 10           5.4          3.7           1.5          0.2
# 11           4.8          3.4           1.6          0.2
# 12           4.8          3.0           1.4          0.1
# 13           4.3          3.0           1.1          0.1
# 14           5.8          4.0           1.2          0.2
# ...

# %%
df_iris_virginica = df_iris_virginica.sort_values(by = "petal_length")
df_iris_virginica
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 106           4.9          2.5           4.5          1.7
# 126           6.2          2.8           4.8          1.8
# 138           6.0          3.0           4.8          1.8
# 123           6.3          2.7           4.9          1.8
# 121           5.6          2.8           4.9          2.0
# 127           6.1          3.0           4.9          1.8
# 119           6.0          2.2           5.0          1.5
# 113           5.7          2.5           5.0          2.0
# 146           6.3          2.5           5.0          1.9
# 101           5.8          2.7           5.1          1.9
# 114           5.8          2.8           5.1          2.4
# 142           5.8          2.7           5.1          1.9
# 133           6.3          2.8           5.1          1.5
# 141           6.9          3.1           5.1          2.3
# 149           5.9          3.0           5.1          1.8
# ...

# %%
df_iris_virginica = df_iris_virginica[["petal_length", "petal_width", "sepal_length", "sepal_width"]]
df_iris_virginica
# Out:
#      petal_length  petal_width  sepal_length  sepal_width
# 106           4.5          1.7           4.9          2.5
# 126           4.8          1.8           6.2          2.8
# 138           4.8          1.8           6.0          3.0
# 123           4.9          1.8           6.3          2.7
# 121           4.9          2.0           5.6          2.8
# 127           4.9          1.8           6.1          3.0
# 119           5.0          1.5           6.0          2.2
# 113           5.0          2.0           5.7          2.5
# 146           5.0          1.9           6.3          2.5
# 101           5.1          1.9           5.8          2.7
# 114           5.1          2.4           5.8          2.8
# 142           5.1          1.9           5.8          2.7
# 133           5.1          1.5           6.3          2.8
# 141           5.1          2.3           6.9          3.1
# 149           5.1          1.8           5.9          3.0
# ...

# %%
df_market = pd.read_excel("Supermarket-Sales-Sample-Data.xlsx")
df_market
# Out:
#     Order No Order Date       Customer Name  Ship Date  Retail Price (USD)  \
# 0       1001 2024-01-01          John Smith 2024-01-03               49.99
# 1       1002 2024-01-01            Jane Doe 2024-01-04               29.99
# 2       1003 2024-01-02     Michael Johnson 2024-01-07               99.99
# 3       1004 2024-01-02         Emily Brown 2024-01-03               19.99
# 4       1005 2024-01-03        David Wilson 2024-01-08              149.99
# ..       ...        ...                 ...        ...                 ...
# 65      1066 2024-02-02      Sarah Gonzalez 2024-02-06               79.99
# 66      1067 2024-02-03       Matthew Smith 2024-02-06               49.99
# 67      1068 2024-02-04       Emily Johnson 2024-02-05              129.99
# 68      1069 2024-02-04        Daniel Brown 2024-02-08               19.99
# 69      1070 2024-02-04  Jennifer Hernandez 2024-02-07              149.99
#
#     Order Quantity
# 0                2
# 1                1
# ...

# %%
df_market["Order Date"].unique()
# Out:
# <DatetimeArray>
# ['2024-01-01 00:00:00', '2024-01-02 00:00:00', '2024-01-03 00:00:00',
#  '2024-01-04 00:00:00', '2024-01-05 00:00:00', '2024-01-06 00:00:00',
#  '2024-01-07 00:00:00', '2024-01-08 00:00:00', '2024-01-09 00:00:00',
#  '2024-01-10 00:00:00', '2024-01-11 00:00:00', '2024-01-12 00:00:00',
#  '2024-01-13 00:00:00', '2024-01-14 00:00:00', '2024-01-15 00:00:00',
#  '2024-01-16 00:00:00', '2024-01-17 00:00:00', '2024-01-18 00:00:00',
#  '2024-01-19 00:00:00', '2024-01-20 00:00:00', '2024-01-21 00:00:00',
#  '2024-01-22 00:00:00', '2024-01-23 00:00:00', '2024-01-24 00:00:00',
#  '2024-01-25 00:00:00', '2024-01-26 00:00:00', '2024-01-27 00:00:00',
#  '2024-01-28 00:00:00', '2024-01-29 00:00:00', '2024-01-30 00:00:00',
#  '2024-01-31 00:00:00', '2024-02-01 00:00:00', '2024-02-02 00:00:00',
#  '2024-02-03 00:00:00', '2024-02-04 00:00:00']
# Length: 35, dtype: datetime64[ns]

# %%
df_market["Customer Name"].value_counts()
# Out:
# Customer Name
# Emily Brown              3
# David Wilson             3
# Jennifer Davis           3
# Jennifer Hernandez       2
# Daniel Brown             2
# Emily Johnson            2
# Michael Martinez         2
# Matthew Garcia           2
# Sarah Johnson            2
# Matthew Smith            2
# Sarah Gonzalez           2
# Jessica Wilson           2
# David Rodriguez          2
# Jessica Martinez         2
# Daniel Hernandez         2
# Michael Johnson          2
# Jane Doe                 1
# Lisa Taylor              1
# John Smith               1
# Daniel Smith             1
# Laura Brown              1
# James Johnson            1
# Amanda Martinez          1
# Matthew Wilson           1
# Jessica Gonzalez         1
# Richard Perez            1
# Melissa Lopez            1
# William Hernandez        1
# Kimberly Garcia          1
# Christopher Thomas       1
# Sarah Anderson           1
# Daniel Martinez          1
# Christopher Rodriguez    1
# ...

# %%
df_market["Ship Date"].unique()
# Out:
# <DatetimeArray>
# ['2024-01-03 00:00:00', '2024-01-04 00:00:00', '2024-01-07 00:00:00',
#  '2024-01-08 00:00:00', '2024-01-06 00:00:00', '2024-01-09 00:00:00',
#  '2024-01-12 00:00:00', '2024-01-13 00:00:00', '2024-01-14 00:00:00',
#  '2024-01-11 00:00:00', '2024-01-15 00:00:00', '2024-01-17 00:00:00',
#  '2024-01-18 00:00:00', '2024-01-19 00:00:00', '2024-01-23 00:00:00',
#  '2024-01-20 00:00:00', '2024-01-22 00:00:00', '2024-01-24 00:00:00',
#  '2024-01-21 00:00:00', '2024-01-26 00:00:00', '2024-01-25 00:00:00',
#  '2024-01-27 00:00:00', '2024-01-30 00:00:00', '2024-01-29 00:00:00',
#  '2024-01-28 00:00:00', '2024-01-31 00:00:00', '2024-02-01 00:00:00',
#  '2024-02-02 00:00:00', '2024-02-04 00:00:00', '2024-02-05 00:00:00',
#  '2024-02-03 00:00:00', '2024-02-06 00:00:00', '2024-02-08 00:00:00',
#  '2024-02-07 00:00:00']
# Length: 34, dtype: datetime64[ns]

# %%
df_market["Ship Date"].value_counts()
# Out:
# Ship Date
# 2024-01-19    7
# 2024-01-14    4
# 2024-01-17    4
# 2024-01-31    4
# 2024-01-25    3
# 2024-01-29    3
# 2024-01-12    3
# 2024-01-06    3
# 2024-01-26    3
# 2024-01-08    3
# 2024-02-06    2
# 2024-01-03    2
# 2024-01-27    2
# 2024-01-30    2
# 2024-01-23    2
# 2024-02-05    2
# 2024-01-09    2
# 2024-01-07    2
# 2024-02-02    2
# 2024-01-04    1
# 2024-01-20    1
# 2024-01-22    1
# 2024-01-15    1
# 2024-01-11    1
# 2024-01-13    1
# 2024-01-18    1
# 2024-01-24    1
# 2024-01-21    1
# 2024-01-28    1
# 2024-02-01    1
# 2024-02-04    1
# 2024-02-03    1
# 2024-02-08    1
# 2024-02-07    1
# Name: count, dtype: int64

# %%
df_market["Retail Price (USD)"].unique()
# Out:
# array([ 49.99,  29.99,  99.99,  19.99, 149.99,  79.99,  39.99,  69.99,
#         89.99, 199.99, 129.99])

# %%
df_market["Order Quantity"].unique()
# Out:
# array([2, 1, 3, 4, 5])

# %%
df_market2 = df_market[(df_market["Customer Name"] == "David Wilson") | (df_market["Customer Name"] == "Emily Brown")]
df_market2
# Out:
#     Order No Order Date Customer Name  Ship Date  Retail Price (USD)  \
# 3       1004 2024-01-02   Emily Brown 2024-01-03               19.99
# 4       1005 2024-01-03  David Wilson 2024-01-08              149.99
# 24      1025 2024-01-13  David Wilson 2024-01-17              149.99
# 40      1041 2024-01-21  David Wilson 2024-01-26              129.99
# 43      1044 2024-01-22   Emily Brown 2024-01-25               69.99
# 59      1060 2024-01-30   Emily Brown 2024-02-01               19.99
#
#     Order Quantity
# 3                4
# 4                1
# 24               1
# 40               1
# 43               2
# 59               4

# %%
df_market.insert(4, "Total", df_market["Retail Price (USD)"] * df_market["Order Quantity"])

# %%
df_market
# Out:
#     Order No Order Date       Customer Name  Ship Date   Total  \
# 0       1001 2024-01-01          John Smith 2024-01-03   99.98
# 1       1002 2024-01-01            Jane Doe 2024-01-04   29.99
# 2       1003 2024-01-02     Michael Johnson 2024-01-07  299.97
# 3       1004 2024-01-02         Emily Brown 2024-01-03   79.96
# 4       1005 2024-01-03        David Wilson 2024-01-08  149.99
# ..       ...        ...                 ...        ...     ...
# 65      1066 2024-02-02      Sarah Gonzalez 2024-02-06  159.98
# 66      1067 2024-02-03       Matthew Smith 2024-02-06  149.97
# 67      1068 2024-02-04       Emily Johnson 2024-02-05  129.99
# 68      1069 2024-02-04        Daniel Brown 2024-02-08   79.96
# 69      1070 2024-02-04  Jennifer Hernandez 2024-02-07  149.99
#
#     Retail Price (USD)  Order Quantity
# 0                49.99               2
# 1                29.99               1
# 2                99.99               3
# 3                19.99               4
# ...

# %%
#df_market["Total"] = df_market["Retail Price (USD)"] * df_market["Order Quantity"]
df_market
# Out:
#     Order No Order Date       Customer Name  Ship Date   Total  \
# 0       1001 2024-01-01          John Smith 2024-01-03   99.98
# 1       1002 2024-01-01            Jane Doe 2024-01-04   29.99
# 2       1003 2024-01-02     Michael Johnson 2024-01-07  299.97
# 3       1004 2024-01-02         Emily Brown 2024-01-03   79.96
# 4       1005 2024-01-03        David Wilson 2024-01-08  149.99
# ..       ...        ...                 ...        ...     ...
# 65      1066 2024-02-02      Sarah Gonzalez 2024-02-06  159.98
# 66      1067 2024-02-03       Matthew Smith 2024-02-06  149.97
# 67      1068 2024-02-04       Emily Johnson 2024-02-05  129.99
# 68      1069 2024-02-04        Daniel Brown 2024-02-08   79.96
# 69      1070 2024-02-04  Jennifer Hernandez 2024-02-07  149.99
#
#     Retail Price (USD)  Order Quantity
# 0                49.99               2
# 1                29.99               1
# 2                99.99               3
# 3                19.99               4
# ...

# %%
df_market = df_market[["Order Date", "Ship Date", "Order No", "Customer Name", "Total", "Retail Price (USD)", "Order Quantity"]]
df_market
# Out:
#    Order Date  Ship Date  Order No       Customer Name   Total  \
# 0  2024-01-01 2024-01-03      1001          John Smith   99.98
# 1  2024-01-01 2024-01-04      1002            Jane Doe   29.99
# 2  2024-01-02 2024-01-07      1003     Michael Johnson  299.97
# 3  2024-01-02 2024-01-03      1004         Emily Brown   79.96
# 4  2024-01-03 2024-01-08      1005        David Wilson  149.99
# ..        ...        ...       ...                 ...     ...
# 65 2024-02-02 2024-02-06      1066      Sarah Gonzalez  159.98
# 66 2024-02-03 2024-02-06      1067       Matthew Smith  149.97
# 67 2024-02-04 2024-02-05      1068       Emily Johnson  129.99
# 68 2024-02-04 2024-02-08      1069        Daniel Brown   79.96
# 69 2024-02-04 2024-02-07      1070  Jennifer Hernandez  149.99
#
#     Retail Price (USD)  Order Quantity
# 0                49.99               2
# 1                29.99               1
# 2                99.99               3
# 3                19.99               4
# ...

# %%
df_market_client = df_market[["Customer Name", "Total"]]
df_market_client
# Out:
#          Customer Name   Total
# 0           John Smith   99.98
# 1             Jane Doe   29.99
# 2      Michael Johnson  299.97
# 3          Emily Brown   79.96
# 4         David Wilson  149.99
# ..                 ...     ...
# 65      Sarah Gonzalez  159.98
# 66       Matthew Smith  149.97
# 67       Emily Johnson  129.99
# 68        Daniel Brown   79.96
# 69  Jennifer Hernandez  149.99
#
# [70 rows x 2 columns]

# %%
df_client = df_market_client.groupby(by = "Customer Name").sum().reset_index()
df_client
# Out:
#             Customer Name   Total
# 0         Amanda Martinez  149.99
# 1           Amy Hernandez  149.97
# 2   Christopher Rodriguez  129.99
# 3      Christopher Thomas   89.99
# 4            Daniel Brown  219.94
# 5            Daniel Davis  199.99
# 6        Daniel Hernandez  269.96
# 7         Daniel Martinez  119.97
# 8            Daniel Smith  199.99
# 9           Daniel Wilson  149.95
# 10            David Brown   79.96
# 11         David Martinez  159.98
# 12        David Rodriguez  299.92
# 13           David Wilson  429.97
# 14            Emily Brown  299.90
# 15            Emily Davis  199.99
# 16          Emily Johnson  279.98
# 17        Emily Rodriguez  119.97
# 18          James Johnson  139.98
# 19               Jane Doe   29.99
# 20         Jennifer Davis  489.92
# 21     Jennifer Hernandez  269.96
# 22      Jennifer Martinez  159.98
# 23         Jennifer Smith  149.95
# 24       Jessica Gonzalez  129.99
# 25        Jessica Johnson  129.99
# ...

# %%
df_client.sort_values(by = "Total", ascending = False).head(10)
# Out:
#          Customer Name   Total
# 20      Jennifer Davis  489.92
# 41     Michael Johnson  459.95
# 13        David Wilson  429.97
# 28      Jessica Wilson  359.97
# 12     David Rodriguez  299.92
# 14         Emily Brown  299.90
# 47      Sarah Gonzalez  289.97
# 16       Emily Johnson  279.98
# 33      Matthew Garcia  279.98
# 21  Jennifer Hernandez  269.96

# %%
df_iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df_iris_numerico = df_iris.drop(columns = "species")
df_iris_numerico.corr()
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000

# %%
import seaborn as sns

# %%
sns.pairplot(data = df_iris, hue = "species")

# %%
datos = {"Nombre" : ["Jose", "Maria", "Leonardo", "Isaac"],
         "Edad" : np.array([30, 27, 45, 35]),
         "Sexo" : ["H", "M", "H", "H"]}

datos
# Out:
# {'Nombre': ['Jose', 'Maria', 'Leonardo', 'Isaac'],
#  'Edad': array([30, 27, 45, 35]),
#  'Sexo': ['H', 'M', 'H', 'H']}

# %%
df = pd.DataFrame(datos)
df
# Out:
#      Nombre  Edad Sexo
# 0      Jose    30    H
# 1     Maria    27    M
# 2  Leonardo    45    H
# 3     Isaac    35    H

# %%
calificaciones = {"Nombre" : ["Jose", "Maria", "Leonardo", "Isaac"],
                  "Calificacion" : [7, 9, 10, 9]}

df_calificaciones = pd.DataFrame(calificaciones)
df_calificaciones
# Out:
#      Nombre  Calificacion
# 0      Jose             7
# 1     Maria             9
# 2  Leonardo            10
# 3     Isaac             9

# %%
df_completo = pd.merge(df, df_calificaciones, "inner", on = "Nombre")
df_completo
# Out:
#      Nombre  Edad Sexo  Calificacion
# 0      Jose    30    H             7
# 1     Maria    27    M             9
# 2  Leonardo    45    H            10
# 3     Isaac    35    H             9

# %%
sns.set_theme(style="whitegrid")

# %%
diamonds = sns.load_dataset("diamonds")
diamonds
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
sns.displot(
    data=diamonds,
    x="carat", hue="cut",
    kind="kde", height=6,
    multiple="fill", clip=(0, None),
    palette="ch:rot=-.25,hue=1,light=.75",
)

# %%
sns.set_theme(style="darkgrid")

# %%
tips = sns.load_dataset("tips")
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
g = sns.jointplot(x="total_bill", y="tip", data=tips,
                  kind="reg", truncate=False,
                  xlim=(0, 60), ylim=(0, 12),
                  color="m", height=7
                  )
